# %% [markdown]
# ## RNN Definition

# %%
import os
import random
from PIL import Image


# Path to the folder containing images
folder_path = "/captcha_dataset"

# Get a list of all image files in the folder
image_files = [f for f in os.listdir(folder_path) if f.lower().endswith(('.png', '.jpg', '.jpeg', '.gif'))]

# Check if there are any image files
if not image_files:
    print("No image files found in the folder.")
else:
    # Select a random image file
    random_image_file = random.choice(image_files)

    # Open and display the random image
    image_path = os.path.join(folder_path, random_image_file)
    img = Image.open(image_path)
    img.show()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[13], line 9
#       6 folder_path = "/captcha_dataset"
#       8 # Get a list of all image files in the folder
# ----> 9 image_files = [f for f in os.listdir(folder_path) if f.lower().endswith(('.png', '.jpg', '.jpeg', '.gif'))]
#      11 # Check if there are any image files
#      12 if not image_files:
#
# FileNotFoundError: [WinError 3] The system cannot find the path specified: '/captcha_dataset'

# %%
# Test push to Github
from pathlib import Path
from PIL import Image
current_directory = Path.cwd()
import random
import matplotlib.pyplot as plt

parent_directory = current_directory.parent
path_to_dataset =str(parent_directory)+'/captcha_dataset'
captchas = os.listdir(path_to_dataset)

image = Image.open(os.path.join(path_to_dataset, random.choice(captchas)))
plt.imshow(image)
plt.axis('off')
plt.show()
